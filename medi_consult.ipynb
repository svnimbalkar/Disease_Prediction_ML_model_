# %%
from tkinter import *  #package for interface
import numpy as np     #library for working with arrays
import pandas as pd    #library use to analyze data
from sklearn.model_selection import cross_val_score

# from gui_stuff import *

#l1 for symptoms
l1=['back_pain','constipation','abdominal_pain','diarrhoea','mild_fever','yellow_urine',
'yellowing_of_eyes','acute_liver_failure','fluid_overload','swelling_of_stomach',
'swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs',
'fast_heart_rate','pain_during_bowel_movements','pain_in_anal_region','bloody_stool',
'irritation_in_anus','neck_pain','dizziness','cramps','bruising','obesity','swollen_legs',
'swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips',
'slurred_speech','knee_pain','hip_joint_pain','muscle_weakness','stiff_neck','swelling_joints',
'movement_stiffness','spinning_movements','loss_of_balance','unsteadiness',
'weakness_of_one_body_side','loss_of_smell','bladder_discomfort','foul_smell_of urine',
'continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain',
'abnormal_menstruation','dischromic _patches','watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum',
'rusty_sputum','lack_of_concentration','visual_disturbances','receiving_blood_transfusion',
'receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen',
'history_of_alcohol_consumption','fluid_overload','blood_in_sputum','prominent_veins_on_calf',
'palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose',
'yellow_crust_ooze']

#diseases
disease=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
' Migraine','Cervical spondylosis',
'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']

l2=[]
for x in range(0,len(l1)):     #looping from 0 to last index of l1
    l2.append(0)               #inserts single element in list

# TRAINING DATA df -------------------------------------------------------------------------------------
df=pd.read_csv("Downloads\Training.csv")

#to replace a phrase with another phrase
df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)  #inplace true means operation on dataset doesn't changes

# print(df.head())

X= df[l1]  #list of symptoms (x:symptoms is independent variable)

y = df[["prognosis"]] #list of diseases (y:disease is dependent variable)
np.ravel(y)           #numpy.ravel() returns flattened array i.e 1D array for diseases
# print(y)

# TESTING DATA tr --------------------------------------------------------------------------------
tr=pd.read_csv("Downloads\Testing.csv")
tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)

X_test= tr[l1]  #list of symptoms 
y_test = tr[["prognosis"]] #list of diseases
np.ravel(y_test)  #1D array
# ------------------------------------------------------------------------------------------------------

def DecisionTree():

    from sklearn import tree  #to import decision tree
    from sklearn.model_selection import cross_val_score, GridSearchCV# to measure quality of split cross verification
    from sklearn import metrics#implements several loss, score(accuracy score),utility function
    from sklearn.metrics import confusion_matrix
    from sklearn.model_selection import RandomizedSearchCV#implementation of fit and score methods
    from sklearn.metrics import classification_report#used to check the quality of classification algorithm


    clf3 = tree.DecisionTreeClassifier(max_depth=8,criterion='entropy')   # empty model of the decision tree
    cv_scores = cross_val_score(clf3, X, y, cv=10, scoring='accuracy')
    clf3 = clf3.fit(X,y)  # estimator for classification 

    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score 
    y_pred1=clf3.predict(X_test) #symptoms
    #print(accuracy_score(y_test, y_pred1))
    #print(accuracy_score(y_test, y_pred1,normalize=False))
    cm= confusion_matrix(y_test,y_pred1)
    
    print(classification_report(y_test, y_pred1))
    TP=cm[0][0]
    TN=cm[1][1]
    FN=cm[1][0]
    FP=cm[0][1]
    print('Accuracy of decision tree')
    print(round(accuracy_score(y_pred1,y_test)*100,2))
    print('Testing Accuracy for Decision Tree:',(TP+TN)/(TP+TN+FN+FP))
   # print('Testing Sensitivity for Decision Tree:',(TP/(TP+FN)))
   # print('Testing Specificity for Decision Tree:',(TN/(TN+FP)))
   # print('Testing Precision for Decision Tree:',(TP/(TP+FP)))
    # -----------------------------------------------------

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]

    for k in range(0,len(l1)):  # for loop for symptom from dataset
        # print (k)
        for z in psymptoms:    # for loop for symptom from user
            if(z==l1[k]):      # if symptom matches then set l2
                l2[k]=1

    inputtest = [l2]
    predict = clf3.predict(inputtest) #pass the symptom for disease prediction
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):  
        if(predicted == a):       # match symptom with disease from dataset
            h='yes'
            break


    if (h=='yes'):
        t1.delete("1.0", END)
        t1.insert(END, disease[a])
    else:
        t1.delete("1.0", END)
        t1.insert(END, "Not Found")


def randomforest():
    from sklearn.ensemble import RandomForestClassifier#random forest is model of emsembled
    
    clf4 = RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=8,min_samples_split=5)
    clf9 = clf4.fit(X,np.ravel(y))  #here in clf4 we are fitting symptoms and fitiing 1D array symptoms and disease

    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score #from sklearn importing accuracy score to scheck
    from sklearn.metrics import f1_score 
    from sklearn import metrics
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    y_pred2=clf9.predict(X_test)  #variable y_pred to get prediction from x test set(Symptoms)
    #print(accuracy_score(y_test, y_pred2))
    #print(f1_score(y_test, y_pred2,average='weighted'))
    #print(accuracy_score(y_test, y_pred2,normalize=False))
    cm3=confusion_matrix(y_test, y_pred2)
    TP=cm3[0][0]
    TN=cm3[1][1]
    FN=cm3[1][0]
    FP=cm3[0][1]
    print('')
    print('Accuracy of random forest')
    print(round(accuracy_score(y_pred2,y_test)*100,2))
    print('Testing Accuracy for Random Forest:',(TP+TN)/(TP+TN+FN+FP))
   # print('Testing Sensitivity for Random Forest:',(TP/(TP+FN)))
    #print('Testing Specificity for Random Forest:',(TN/(TN+FP)))
    #print('Testing Precision for Random Forest:',(TP/(TP+FP)))
    print(classification_report(y_test, y_pred2))
    # -----------------------------------------------------

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]

    for k in range(0,len(l1)):#from 0 to whole only one symptoms
        for z in psymptoms:  
            if(z==l1[k]):
                l2[k]=1   #if matches then 1

    inputtest = [l2]#symptom having 1(correct)
    predict = clf4.predict(inputtest)#which we have predicted 1
    predicted=predict[0]#nothing here as 0
#disease
    h='no'#default no
    for a in range(0,len(disease)):#0 to all disease
        if(predicted == a):#symptoms matches from dataset
            h='yes'
            break#out from loop as we got already

    if (h=='yes'):
        t2.delete("1.0", END)
        t2.insert(END, disease[a])#above loop
    else:
        t2.delete("1.0", END)
        t2.insert(END, "Not Found")#still not found


def NaiveBayes(): #other symptom not dependent on each other each prediction is independent
    from sklearn.naive_bayes import GaussianNB #importing for naive bayes
    gnb = GaussianNB()
    gnb=gnb.fit(X,np.ravel(y))

    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score
    
    y_pred3=gnb.predict(X_test)
    print(accuracy_score(y_test, y_pred3))
    print(f1_score(y_test, y_pred3,average='weighted'))
    print(accuracy_score(y_test, y_pred3,normalize=False))
    # -----------------------------------------------------

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1

    inputtest = [l2]
    predict = gnb.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):
        if(predicted == a):
            h='yes'
            break

    if (h=='yes'):
        t3.delete("1.0", END)
        t3.insert(END, disease[a])
    else:
        t3.delete("1.0", END)
        t3.insert(END, "Not Found")

# gui_stuff------------------------------------------------------------------------------------

root = Tk()                            # tkinter is assign to variable root
root.configure(background='black')

# entry variables
Symptom1 = StringVar()           # Define entry veriable
Symptom1.set(None)               # which are in string datatype and by default set at None value
Symptom2 = StringVar()             
Symptom2.set(None)
Symptom3 = StringVar()
Symptom3.set(None)
Symptom4 = StringVar()
Symptom4.set(None)
Symptom5 = StringVar()
Symptom5.set(None)
Name = StringVar()

# Heading
w2 = Label(root, justify=LEFT, text="Disease Predictor using Machine Learning", fg="white", bg="black")
w2.config(font=("Elephant", 30))
w2.grid(row=1, column=0, columnspan=2, padx=100)                                   #this is gui part 
w2 = Label(root, justify=LEFT, text="MEDI_CONSULT", fg="white", bg="black")
w2.config(font=("Aharoni", 30))
w2.grid(row=2, column=0, columnspan=2, padx=100)

# labels
NameLb = Label(root, text="Name of the Patient", fg="black", bg="white")
NameLb.grid(row=8, column=1, pady=15, sticky=W)

S1Lb = Label(root, text="Symptom 1", bg="white", fg="black")
S1Lb.grid(row=9, column=1, pady=10, sticky=W)

S2Lb = Label(root, text="Symptom 2", bg="white", fg="black")
S2Lb.grid(row=10, column=1, pady=10, sticky=W)

S3Lb = Label(root, text="Symptom 3", bg="white", fg="black")
S3Lb.grid(row=11, column=1, pady=10, sticky=W)

S4Lb = Label(root, text="Symptom 4", bg="white", fg="black")
S4Lb.grid(row=12, column=1, pady=10, sticky=W)

S5Lb = Label(root, text="Symptom 5", bg="white", fg="black")
S5Lb.grid(row=13, column=1, pady=10, sticky=W)


lrLb = Label(root, text="DecisionTree", fg="white", bg="red")
lrLb.grid(row=17, column=1, pady=10,sticky=W)

destreeLb = Label(root, text="RandomForest", fg="white", bg="red")
destreeLb.grid(row=18, column=1, pady=10, sticky=W)

ranfLb = Label(root, text="NaiveBayes", fg="white", bg="red")
ranfLb.grid(row=20, column=1, pady=10, sticky=W)

# entries
OPTIONS = sorted(l1)

NameEn = Entry(root, textvariable=Name)
NameEn.grid(row=8, column=1)

S1En = OptionMenu(root, Symptom1,*OPTIONS)
S1En.grid(row=9, column=1)

S2En = OptionMenu(root, Symptom2,*OPTIONS)
S2En.grid(row=10, column=1)

S3En = OptionMenu(root, Symptom3,*OPTIONS)
S3En.grid(row=11, column=1)

S4En = OptionMenu(root, Symptom4,*OPTIONS)
S4En.grid(row=12, column=1)

S5En = OptionMenu(root, Symptom5,*OPTIONS)
S5En.grid(row=13, column=1)


dst = Button(root, text="DecisionTree", command=DecisionTree,bg="green",fg="white")
dst.grid(row=10, column=2,padx=10)

rnf = Button(root, text="Randomforest", command=randomforest,bg="green",fg="white")
rnf.grid(row=11, column=2,padx=10)

lr = Button(root, text="NaiveBayes", command=NaiveBayes,bg="green",fg="white")
lr.grid(row=12, column=2,padx=10)

#textfileds
t1 = Text(root, height=1, width=40,bg="orange",fg="black")
t1.grid(row=17, column=1, padx=10)

t2 = Text(root, height=1, width=40,bg="orange",fg="black")
t2.grid(row=18, column=1 , padx=10)

t3 = Text(root, height=1, width=40,bg="orange",fg="black")
t3.grid(row=20, column=1 , padx=10)

root.mainloop()
